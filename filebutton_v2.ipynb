# %%
import os
import ipywidgets as widgets

class FileBrowser(object):
    def __init__(self):
        self.path = os.getcwd()
        self._update_files()

    def _update_files(self):
        self.files = list()
        self.dirs = list()
        if(os.path.isdir(self.path)):
            for f in os.listdir(self.path):
                ff = os.path.join(self.path, f)
                if os.path.isdir(ff):
                    self.dirs.append(f)
                else:
                    self.files.append(f)

    def widget(self):
        box = widgets.VBox()
        self._update(box)
        return box

    def _update(self, box):

        def on_click(b):
            if b.description == '..':
                self.path = os.path.split(self.path)[0]
            else:
                self.path = os.path.join(self.path, b.description)
            self._update_files()
            self._update(box)

        buttons = []
        if self.files:
            button = widgets.Button(description='..', background_color='#d0d0ff')
            button.on_click(on_click)
            buttons.append(button)
        for f in self.dirs:
            button = widgets.Button(description=f, background_color='#d0d0ff')
            button.on_click(on_click)
            buttons.append(button)
        for f in self.files:
            button = widgets.Button(description=f)
            button.on_click(on_click)
            buttons.append(button)
        box.children = tuple([widgets.HTML("<h2>%s</h2>" % (self.path,))] + buttons)

# %%
f = FileBrowser()
f.widget()
# Out:
# VBox(children=(HTML(value='<h2>C:\\Users\\venalap3</h2>'), Button(description='..', style=ButtonStyle()), Butt…

# %%
#   <interact with widget, select a path>
# in a separate cell:
f.path # returns the selected path
# Out:
# 'C:\\Users\\venalap3\\Downloads\\desktop.ini'

# %%
from IPython.display import display
import fileupload

uploader = fileupload.FileUploadWidget()

def _handle_upload(change):
    w = change['owner']
    with open(w.filename, 'wb') as f:
        f.write(w.data)
    print('Uploaded `{}` ({:.2f} kB)'.format(
        w.filename, len(w.data) / 2**10))

uploader.observe(_handle_upload, names='data')

display(uploader)
# Out:
# FileUploadWidget(label='Browse', _dom_classes=('widget_item', 'btn-group'))
# Uploaded `30_11_18_1500_35_50i_no_Aperture_ADL.csv` (17.02 kB)
# Uploaded `051018_1500_35_20i_noAperture.csv` (41.04 kB)

# %%
uploader.filename
# Out:
# '051018_1500_35_20i_noAperture.csv'

# %%
import pandas as pd

# %%
data = pd.read_csv(uploader.filename, sep=',')

# %%
data
# Out:
#                                S-Polarization Baseline      Unnamed: 1  \
# 0                                      Wavelength (nm)              %T
# 1                                                  780     32.26517868
# 2                                                  770     31.73974991
# 3                                                  760     31.17285919
# 4                                                  750     30.50868034
# 5                                                  740     29.74102974
# 6                                                  730     28.81381035
# 7                                                  720     27.67435074
# 8                                                  710     26.26265907
# 9                                                  700     24.50470924
# 10                                                 690     22.37989044
# 11                                                 680     19.89979935
# 12                                                 670     17.24798012
# 13                                                 660     14.85684013
# 14                                                 650     13.48348045
# 15                                                 640     14.00111961
# 16                                                 630      16.7593708
# 17                                                 620     20.01301003
# 18                                                 610     20.15929985
# 19                                                 600     18.16643906
# 20                                                 590     21.55384064
# 21                                                 580     31.18989944
# 22                                                 570     40.18478012
# 23                                                 560     43.58700943
# 24                                                 550     45.16625977
# 25                                                 540      44.5282402
# 26                                                 530     43.57548141
# 27                                                 520     43.03007126
# 28                                                 510     42.45674896
# 29                                                 500     41.75350189
# ..                                                 ...             ...
# 597                                             p0/-90             NaN
# 598              Collection Time: 10/5/2018 1:36:52 PM             NaN
# 599                                   Operator Name  :             NaN
# 600                            Scan Version 6.1.0.1568             NaN
# 601                                   Parameter List :             NaN
# 602                               Instrument  Cary 300             NaN
# 603                           Instrument Version  0.00             NaN
# 604                                   Method Log     :             NaN
# 605                                   Method Name    :             NaN
# 606              Date/Time stamp: 10/5/2018 1:14:21 PM             NaN
# 607                              Method Modifications:             NaN
# 608         NIR interval Changed: 10/5/2018 1:14:33 PM   Old:   -0.020
# 609            AVASRA On Changed: 10/5/2018 1:16:03 PM         Old:OFF
# 610         Idpt Control Changed: 10/5/2018 1:16:03 PM           Old:0
# 611     Measurement Mode Changed: 10/5/2018 1:16:03 PM           Old:0
# 612      NIR Interval nm Changed: 10/5/2018 1:16:03 PM   Old:    0.020
# 613    Source changeover Changed: 10/5/2018 1:16:03 PM   Old:   350.00
# 614  Detector changeover Changed: 10/5/2018 1:16:03 PM   Old:   800.00
# 615   Grating changeover Changed: 10/5/2018 1:16:03 PM   Old:   800.00
# 616          Slit Height Changed: 10/5/2018 1:16:03 PM        Old:Full
# 617                  SBW Changed: 10/5/2018 1:16:03 PM       Old:2.000
# 618       NIR slit width Changed: 10/5/2018 1:16:03 PM       Old:4.000
# 619    Common Slit Width Changed: 10/5/2018 1:16:03 PM       Old:2.000
# 620            UVVIS SAT Changed: 10/5/2018 1:16:04 PM      Old: 0.100
# 621              NIR SAT Changed: 10/5/2018 1:16:04 PM      Old: 0.100
# 622           Common SAT Changed: 10/5/2018 1:16:04 PM      Old: 0.100
# 623               Y mode Changed: 10/5/2018 1:16:04 PM         Old:Abs
# 624            AVASRA On Changed: 10/5/2018 1:19:55 PM          Old:ON
# 625               Y mode Changed: 10/5/2018 1:35:58 PM          Old:%T
# 626                           End Method Modifications             NaN
#
#     P-Polarization Baseline   Unnamed: 3  Zero Correction       Unnamed: 5  \
# 0           Wavelength (nm)           %T  Wavelength (nm)               %T
# 1                       780  94.90271759              780  -0.005910668056
# 2                       770  95.12696838              770  -0.005696328823
# 3                       760    95.560112              760   -0.00533790607
# 4                       750  96.13165283              750  -0.001894686022
# 5                       740  96.89289856              740      -0.00301488
# 6                       730  97.86157227              730  -0.002662426094
# 7                       720  99.07309723              720  -0.003012106055
# 8                       710  100.5811996              710  -0.003056528978
# 9                       700  102.4644012              700  -0.002115787007
# 10                      690  104.7349014              690  -0.002094851108
# 11                      680  107.4064026              680  -0.001920489012
# 12                      670  110.2697983              670  -0.002149451058
# 13                      660  112.8522034              660  -0.001474534976
# 14                      650  114.2727966              650  -0.001399356057
# 15                      640  113.6766968              640  -0.001634872984
# 16                      630  111.0582962              630  -0.001518681995
# 17                      620  108.3612976              620  -0.002172253095
# 18                      610  109.0224991              610  -0.002124604071
# 19                      600  111.5140991              600  -0.001541889971
# 20                      590  107.6502991              590  -0.001695757965
# 21                      580  98.61553955              580  -0.002036103979
# 22                      570  90.77461243              570  -0.003187705064
# 23                      560   88.2702179              560  -0.002741703996
# 24                      550  87.33525848              550  -0.002998538082
# 25                      540   89.0113678              540  -0.002670259913
# 26                      530  90.34352875              530  -0.002331015887
# 27                      520    91.462883              520  -0.003038424999
# 28                      510  92.64788818              510  -0.002785722958
# 29                      500  93.95693207              500  -0.002760586096
# ..                      ...          ...              ...              ...
# 597                     NaN          NaN              NaN              NaN
# 598                     NaN          NaN              NaN              NaN
# 599                     NaN          NaN              NaN              NaN
# 600                     NaN          NaN              NaN              NaN
# 601                     NaN          NaN              NaN              NaN
# 602                     NaN          NaN              NaN              NaN
# 603                     NaN          NaN              NaN              NaN
# 604                     NaN          NaN              NaN              NaN
# 605                     NaN          NaN              NaN              NaN
# 606                     NaN          NaN              NaN              NaN
# 607                     NaN          NaN              NaN              NaN
# 608           New:   -1.000          NaN              NaN              NaN
# 609                  New:ON          NaN              NaN              NaN
# 610                   New:1          NaN              NaN              NaN
# 611                   New:1          NaN              NaN              NaN
# 612           New:    1.000          NaN              NaN              NaN
# 613           New:   320.00          NaN              NaN              NaN
# 614           New:  1050.00          NaN              NaN              NaN
# 615           New:   830.00          NaN              NaN              NaN
# 616             New:Reduced          NaN              NaN              NaN
# 617               New:5.000          NaN              NaN              NaN
# 618               New:5.000          NaN              NaN              NaN
# 619               New:5.000          NaN              NaN              NaN
# 620              New: 3.000          NaN              NaN              NaN
# 621              New: 3.000          NaN              NaN              NaN
# 622              New: 3.000          NaN              NaN              NaN
# 623                  New:%T          NaN              NaN              NaN
# 624                  New:ON          NaN              NaN              NaN
# 625                  New:%R          NaN              NaN              NaN
# 626                     NaN          NaN              NaN              NaN
#
#               s0/-20    Unnamed: 7           p0/-20    Unnamed: 9     ...      \
# 0    Wavelenght (nm)            %R  Wavelenght (nm)            %R     ...
# 1                780  0.1643546969              780  0.1595358998     ...
# 2                770  0.1604665965              770  0.1579121947     ...
# 3                760  0.1628978997              760  0.1568260044     ...
# 4                750  0.1536808014              750  0.1557517052     ...
# 5                740  0.1569555998              740  0.1565980017     ...
# 6                730  0.1533927023              730  0.1566641033     ...
# 7                720  0.1553635001              720   0.155674696     ...
# 8                710  0.1531707942              710  0.1542402059     ...
# 9                700  0.1516201049              700  0.1534978002     ...
# 10               690  0.1492035985              690  0.1516637057     ...
# 11               680  0.1469064951              680   0.150334999     ...
# 12               670  0.1454862952              670  0.1498100013     ...
# 13               660  0.1449425071              660  0.1491978019     ...
# 14               650  0.1426617056              650   0.148161903     ...
# 15               640  0.1421710998              640  0.1478126943     ...
# 16               630  0.1388247013              630  0.1466971934     ...
# 17               620  0.1413041949              620  0.1460283995     ...
# 18               610  0.1392308027              610  0.1457999051     ...
# 19               600  0.1385993958              600   0.146619007     ...
# 20               590  0.1391732991              590  0.1479368955     ...
# 21               580  0.1436053962              580  0.1511065066     ...
# 22               570  0.1477532983              570  0.1549655944     ...
# 23               560  0.1538410038              560  0.1601043046     ...
# 24               550  0.1612184942              550   0.166878894     ...
# 25               540  0.1691007018              540  0.1725153029     ...
# 26               530   0.178987205              530  0.1782284975     ...
# 27               520  0.1896886975              520  0.1870418042     ...
# 28               510  0.1980679035              510  0.1967080981     ...
# 29               500  0.2104737014              500  0.2115247995     ...
# ..               ...           ...              ...           ...     ...
# 597              NaN           NaN              NaN           NaN     ...
# 598              NaN           NaN              NaN           NaN     ...
# 599              NaN           NaN              NaN           NaN     ...
# 600              NaN           NaN              NaN           NaN     ...
# 601              NaN           NaN              NaN           NaN     ...
# 602              NaN           NaN              NaN           NaN     ...
# 603              NaN           NaN              NaN           NaN     ...
# 604              NaN           NaN              NaN           NaN     ...
# 605              NaN           NaN              NaN           NaN     ...
# 606              NaN           NaN              NaN           NaN     ...
# 607              NaN           NaN              NaN           NaN     ...
# 608              NaN           NaN              NaN           NaN     ...
# 609              NaN           NaN              NaN           NaN     ...
# 610              NaN           NaN              NaN           NaN     ...
# 611              NaN           NaN              NaN           NaN     ...
# 612              NaN           NaN              NaN           NaN     ...
# 613              NaN           NaN              NaN           NaN     ...
# 614              NaN           NaN              NaN           NaN     ...
# 615              NaN           NaN              NaN           NaN     ...
# 616              NaN           NaN              NaN           NaN     ...
# 617              NaN           NaN              NaN           NaN     ...
# 618              NaN           NaN              NaN           NaN     ...
# 619              NaN           NaN              NaN           NaN     ...
# 620              NaN           NaN              NaN           NaN     ...
# 621              NaN           NaN              NaN           NaN     ...
# 622              NaN           NaN              NaN           NaN     ...
# 623              NaN           NaN              NaN           NaN     ...
# 624              NaN           NaN              NaN           NaN     ...
# 625              NaN           NaN              NaN           NaN     ...
# 626              NaN           NaN              NaN           NaN     ...
#
#        Unnamed: 29           s0/-80    Unnamed: 31           p0/-80  \
# 0               %R  Wavelenght (nm)             %R  Wavelenght (nm)
# 1    0.07767020166              780   0.0431641005              780
# 2    0.07731808722              770  0.04061755911              770
# 3    0.07733681053              760  0.03849565983              760
# 4    0.07658580691              750  0.03169346973              750
# 5    0.07797218114              740  0.03721304983              740
# 6    0.07773946971              730  0.03778048977              730
# 7    0.07833770663              720  0.04020610824              720
# 8    0.07821640372              710  0.03779884055              710
# 9    0.07856076956              700  0.04297453165              700
# 10   0.07865411043              690  0.03980800882              690
# 11   0.07941112667              680   0.0410746485              680
# 12   0.08038215339              670  0.04275370017              670
# 13   0.08099895716              660   0.0438086018              660
# 14   0.08156978339              650  0.04381911829              650
# 15    0.0822865963              640  0.04706035927              640
# 16   0.08291765302              630  0.04664276913              630
# 17   0.08408738673              620  0.05059561878              620
# 18   0.08564337343              610  0.05074761063              610
# 19    0.0867292434              600  0.05335509032              600
# 20   0.08740785718              590  0.05517068878              590
# 21   0.08944460005              580  0.05721573904              580
# 22   0.09130740911              570  0.06083567068              570
# 23   0.09288814664              560  0.06357482821              560
# 24   0.09439493716              550  0.06823082268              550
# 25   0.09547056258              540  0.07239860296              540
# 26   0.09708601236              530  0.07401374727              530
# 27    0.1000187024              520  0.08049145341              520
# 28    0.1024096981              510  0.08620367944              510
# 29    0.1062747985              500  0.09424971044              500
# ..             ...              ...            ...              ...
# 597            NaN              NaN            NaN              NaN
# 598            NaN              NaN            NaN              NaN
# 599            NaN              NaN            NaN              NaN
# 600            NaN              NaN            NaN              NaN
# 601            NaN              NaN            NaN              NaN
# 602            NaN              NaN            NaN              NaN
# 603            NaN              NaN            NaN              NaN
# 604            NaN              NaN            NaN              NaN
# 605            NaN              NaN            NaN              NaN
# 606            NaN              NaN            NaN              NaN
# 607            NaN              NaN            NaN              NaN
# 608            NaN              NaN            NaN              NaN
# 609            NaN              NaN            NaN              NaN
# 610            NaN              NaN            NaN              NaN
# 611            NaN              NaN            NaN              NaN
# 612            NaN              NaN            NaN              NaN
# 613            NaN              NaN            NaN              NaN
# 614            NaN              NaN            NaN              NaN
# 615            NaN              NaN            NaN              NaN
# 616            NaN              NaN            NaN              NaN
# 617            NaN              NaN            NaN              NaN
# 618            NaN              NaN            NaN              NaN
# 619            NaN              NaN            NaN              NaN
# 620            NaN              NaN            NaN              NaN
# 621            NaN              NaN            NaN              NaN
# 622            NaN              NaN            NaN              NaN
# 623            NaN              NaN            NaN              NaN
# 624            NaN              NaN            NaN              NaN
# 625            NaN              NaN            NaN              NaN
# 626            NaN              NaN            NaN              NaN
#
#        Unnamed: 33           s0/-90    Unnamed: 35           p0/-90  \
# 0               %R  Wavelenght (nm)             %R  Wavelenght (nm)
# 1    0.03564178944              780  0.02179862931              780
# 2     0.0377192013              770  0.01992750913              770
# 3    0.03583645076              760  0.01843415014              760
# 4    0.03652792051              750  0.01913229004              750
# 5    0.03758542985              740  0.02089316957              740
# 6    0.03833146021              730  0.02133082971              730
# 7    0.03949204087              720  0.02472377941              720
# 8    0.04038238898              710  0.02304759063              710
# 9    0.04161889851              700  0.02514654957              700
# 10   0.04278165102              690  0.02593654953              690
# 11    0.0442931205              680  0.02521052957              680
# 12   0.04555036873              670  0.02725745924              670
# 13   0.04671644047              660  0.02862565033              660
# 14   0.04800290987              650  0.02824312076              650
# 15   0.04973562062              640  0.03009207919              640
# 16   0.05167828128              630  0.03123117052              630
# 17   0.05350390077              620  0.03276143968              620
# 18   0.05585790053              610  0.03531498089              610
# 19   0.05783043057              600  0.03721500933              600
# 20    0.0597153306              590  0.03750203177              590
# 21   0.06335747242              580   0.0417512916              580
# 22   0.06591586024              570  0.04628090933              570
# 23   0.06965955347              560  0.04795220867              560
# 24   0.07368031144              550  0.05233265087              550
# 25   0.07777512819              540  0.05609282106              540
# 26   0.08314059675              530  0.05971923098              530
# 27   0.08982723951              520  0.06872160733              520
# 28   0.09619519114              510  0.07511051744              510
# 29    0.1050060019              500  0.08249177039              500
# ..             ...              ...            ...              ...
# 597            NaN              NaN            NaN              NaN
# 598            NaN              NaN            NaN              NaN
# 599            NaN              NaN            NaN              NaN
# 600            NaN              NaN            NaN              NaN
# 601            NaN              NaN            NaN              NaN
# 602            NaN              NaN            NaN              NaN
# 603            NaN              NaN            NaN              NaN
# 604            NaN              NaN            NaN              NaN
# 605            NaN              NaN            NaN              NaN
# 606            NaN              NaN            NaN              NaN
# 607            NaN              NaN            NaN              NaN
# 608            NaN              NaN            NaN              NaN
# 609            NaN              NaN            NaN              NaN
# 610            NaN              NaN            NaN              NaN
# 611            NaN              NaN            NaN              NaN
# 612            NaN              NaN            NaN              NaN
# 613            NaN              NaN            NaN              NaN
# 614            NaN              NaN            NaN              NaN
# 615            NaN              NaN            NaN              NaN
# 616            NaN              NaN            NaN              NaN
# 617            NaN              NaN            NaN              NaN
# 618            NaN              NaN            NaN              NaN
# 619            NaN              NaN            NaN              NaN
# 620            NaN              NaN            NaN              NaN
# 621            NaN              NaN            NaN              NaN
# 622            NaN              NaN            NaN              NaN
# 623            NaN              NaN            NaN              NaN
# 624            NaN              NaN            NaN              NaN
# 625            NaN              NaN            NaN              NaN
# 626            NaN              NaN            NaN              NaN
#
#        Unnamed: 37 Unnamed: 38
# 0               %R         NaN
# 1    0.02040844038         NaN
# 2    0.02236768045         NaN
# 3    0.02206829935         NaN
# 4    0.02083677985         NaN
# 5    0.02203145064         NaN
# 6     0.0225620009         NaN
# 7    0.02465745993         NaN
# 8    0.02524623089         NaN
# 9    0.02588970028         NaN
# 10   0.02751298063         NaN
# 11   0.02873677015         NaN
# 12   0.02935459092         NaN
# 13   0.03071759082         NaN
# 14   0.03208015114         NaN
# 15   0.03425110877         NaN
# 16   0.03608971089         NaN
# 17   0.03858860955         NaN
# 18   0.04074548185         NaN
# 19   0.04325027019         NaN
# 20   0.04555195943         NaN
# 21   0.04913881049         NaN
# 22   0.05270798877         NaN
# 23   0.05689686164         NaN
# 24   0.06237079948         NaN
# 25   0.06969275326         NaN
# 26    0.0797406733         NaN
# 27   0.08955036849         NaN
# 28    0.1004581004         NaN
# 29    0.1107783988         NaN
# ..             ...         ...
# 597            NaN         NaN
# 598            NaN         NaN
# 599            NaN         NaN
# 600            NaN         NaN
# 601            NaN         NaN
# 602            NaN         NaN
# 603            NaN         NaN
# 604            NaN         NaN
# 605            NaN         NaN
# 606            NaN         NaN
# 607            NaN         NaN
# 608            NaN         NaN
# 609            NaN         NaN
# 610            NaN         NaN
# 611            NaN         NaN
# 612            NaN         NaN
# 613            NaN         NaN
# 614            NaN         NaN
# 615            NaN         NaN
# 616            NaN         NaN
# 617            NaN         NaN
# 618            NaN         NaN
# 619            NaN         NaN
# 620            NaN         NaN
# 621            NaN         NaN
# 622            NaN         NaN
# 623            NaN         NaN
# 624            NaN         NaN
# 625            NaN         NaN
# 626            NaN         NaN
#
# [627 rows x 39 columns]
